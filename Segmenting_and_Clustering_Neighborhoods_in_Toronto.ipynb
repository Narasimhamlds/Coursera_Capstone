# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## explore and cluster the neighborhoods in Toronto

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header=0,
                      keep_default_na=False)

# %%
Post_code = tables[0]
Post_code
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %%
Post_code.shape
# Out:
# (180, 3)

# %% [markdown]
# ## Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
Post_code1 = Post_code[Post_code.Borough != 'Not assigned']
Post_code1.columns = ['PostalCode', 'Borough', 'Neighborhood'] 

Post_code1
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# ..         ...               ...
# 160        M8X         Etobicoke
# 165        M4Y  Downtown Toronto
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 178        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# ...

# %%
Post_code1.shape
# Out:
# (103, 3)

# %%
Post_code1.reset_index(drop=True, inplace=True)
Post_code1
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# ...

# %% [markdown]
# ## Checking Duplicate Postal Codes

# %%
Post_code1[Post_code1.PostalCode == 'M5A']
# Out:
#   PostalCode           Borough               Neighborhood
# 2        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
Post_code_merge = Post_code1.groupby('PostalCode')['Neighborhood'].apply(' '.join)
Post_code_merge
# Out:
# PostalCode
# M1B                                       Malvern, Rouge
# M1C               Rouge Hill, Port Union, Highland Creek
# M1E                    Guildwood, Morningside, West Hill
# M1G                                               Woburn
# M1H                                            Cedarbrae
#                              ...
# M9N                                               Weston
# M9P                                            Westmount
# M9R    Kingsview Village, St. Phillips, Martin Grove ...
# M9V    South Steeles, Silverstone, Humbergate, Jamest...
# M9W                  Northwest, West Humber - Clairville
# Name: Neighborhood, Length: 103, dtype: object

# %%
Post_code_merge.shape
# Out:
# (103,)

# %%
Post_code1dup = Post_code1[Post_code1.duplicated(subset=['PostalCode','Borough'])]
Post_code1dup
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
#Checking If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. No records

# %%
Post_code2 = Post_code1[Post_code1.Neighborhood == 'Not assigned']
Post_code2
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
Post_code1
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# ...

# %%
#number of rows in dataframe.

# %%
Post_code1.shape
# Out:
# (103, 3)

# %% [markdown]
# # 2 - Getting the geographical coordinates of each postal code

# %%
import geocoder
lat_lng_coords = None

# %%
lat_lng_coords = None
while(lat_lng_coords is None):
    g= geocoder.google('{}, Toronto, Ontario'.format(Post_code1.PostalCode[0]))
    lat_lng_coords = g.latlng
    print('lat_lnt_coords', lat_lng_coords)

print('latitude', lat_lng_coords[0])
print('langitude', lat_lng_coords[1])
lat_lng_coords = [0]
# Out:
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# lat_lnt_coords None
# ...

# %%
#Didn't get the Latitude and Longitude values by using above method, So using the spread sheet

# %%
lat_lng = pd.read_csv('Geospatial_Coordinates.csv')
lat_lng
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# ..         ...        ...        ...
# 98         M9N  43.706876 -79.518188
# 99         M9P  43.696319 -79.532242
# 100        M9R  43.688905 -79.554724
# 101        M9V  43.739416 -79.588437
# 102        M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
Post_code_latlng = pd.merge(left=Post_code1, right=lat_lng, how='left', left_on='PostalCode', right_on='PostalCode')
Post_code_latlng
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...

# %%
Post_code_latlng.shape
# Out:
# (103, 5)

# %%
Post_code_latlng[Post_code_latlng.Latitude == 0]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
Post_code_latlng[Post_code_latlng.Longitude == 0]
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(Post_code_latlng['Borough'].unique()),
        Post_code_latlng.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %% [markdown]
# # 3 - Explore and cluster the neighborhoods in Toronto

# %%
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import requests # library to handle requests
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values for all the Neighbourhoods
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(Post_code_latlng['Latitude'], Post_code_latlng['Longitude'], Post_code_latlng['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## For Only Neighbourhoods which Borough containing the Toronto

# %%
Post_code_latlng_tor = Post_code_latlng[Post_code_latlng['Borough'].str.contains("Toronto")]
Post_code_latlng_tor
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 4          M7A  Downtown Toronto
# 9          M5B  Downtown Toronto
# 15         M5C  Downtown Toronto
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
# 36         M5J  Downtown Toronto
# 37         M6J      West Toronto
# 41         M4K      East Toronto
# 42         M5K  Downtown Toronto
# 43         M6K      West Toronto
# 47         M4L      East Toronto
# 48         M5L  Downtown Toronto
# 54         M4M      East Toronto
# 61         M4N   Central Toronto
# 62         M5N   Central Toronto
# 67         M4P   Central Toronto
# 68         M5P   Central Toronto
# 69         M6P      West Toronto
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 79         M4S   Central Toronto
# ...

# %%
Post_code_latlng_tor.shape
# Out:
# (39, 5)

# %%
# create map of Tronto using latitude and longitude values
map_toronto1 = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(Post_code_latlng_tor['Latitude'], Post_code_latlng_tor['Longitude'], Post_code_latlng_tor['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto1)  
    
map_toronto1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
